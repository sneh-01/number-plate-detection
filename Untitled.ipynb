# %%
import cv2
import easyocr
import matplotlib.pyplot as plt

# Path to the pre-trained Haar cascade classifier for license plate detection
harcascade = "E:\\number plate\\model\\haarcascade_russian_plate_number.xml"

# Create an EasyOCR reader instance
reader = easyocr.Reader(['en'])

# Provide the path to the uploaded image
image_path = "E:\\number plate\\plates\\car2.png"

# Read the image
img = cv2.imread(image_path)

# Convert the image to grayscale
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Perform license plate detection
plate_cascade = cv2.CascadeClassifier(harcascade)
plates = plate_cascade.detectMultiScale(img_gray, 1.1, 4)

# Iterate over detected license plates
for (x, y, w, h) in plates:
    area = w * h
    if area > min_area:
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
        cv2.putText(img, "Number plate", (x, y), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (255, 0, 255), 2)

        img_roi = img[y: y + h, x: x + w]

        # Read text using EasyOCR
        result = reader.readtext(img_roi)
        print("Number Plate:", result)

# Display the image using matplotlib
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Number Plate: [([[22, 14], [120, 14], [120, 40], [22, 40]], 'As710EL', 0.35540853845574605)]

# %%
import joblib

# Save the EasyOCR reader model as a pickle file
joblib.dump(reader, 'easyocr_model.pkl')
# Out:
# ['easyocr_model.pkl']
